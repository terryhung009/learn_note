# %% [markdown]
# ## ESPN球員球員效率值
#
# [http://insider.espn.com/nba/hollinger/statistics/_/page/1](http://insider.espn.com/nba/hollinger/statistics/_/page/1)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import random

url = 'http://insider.espn.com/nba/hollinger/statistics/_/page/'

try:
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    chrome = webdriver.Chrome(options=options,
                             executable_path='/Users/ryan/Documents/Develope/Python/crawler/chrome_driver/chromedriver')
    chrome.set_page_load_timeout(10)
    for i in range(1, 9):
        _url = url + str(i)
        print(_url)
        chrome.get(_url)
        soup = BeautifulSoup(chrome.page_source, 'html5lib')
        trs = soup.find('tbody').find_all('tr')
        for tr in trs:
            tds = [td for td in tr.children]
            rk = tds[0].text.strip()
            if rk =='RK' or len(tds)<2:
                continue
            name = tds[1].text
            per = tds[11].text
            print('%s :%s' % (name, per))
        wait = random.randint(2,6)
        print('wait time : %d' % wait)
        time.sleep(wait)
    
    
finally:
    chrome.quit()
# Out:
# http://insider.espn.com/nba/hollinger/statistics/_/page/1
# Giannis Antetokounmpo, MIL :31.94
# James Harden, HOU :29.11
# Luka Doncic, DAL :27.65
# Anthony Davis, LAL :27.50
# Damian Lillard, POR :26.95
# Kawhi Leonard, LAC :26.91
# Karl-Anthony Towns, MIN :26.53
# Kyrie Irving, BKN :26.24
# Joel Embiid, PHI :25.82
# LeBron James, LAL :25.55
# Hassan Whiteside, POR :25.07
# Nikola Jokic, DEN :24.97
# Zion Williamson, NO :24.14
# Trae Young, ATL :23.95
# Jimmy Butler, MIA :23.61
# John Collins, ATL :23.59
# Mitchell Robinson, NY :23.51
# Montrezl Harrell, LAC :23.26
# Bradley Beal, WSH :23.22
# Christian Wood, DET :23.22
# Enes Kanter, BOS :22.48
# Jonas Valanciunas, MEM :22.32
# Andre Drummond, CLE/DET :22.08
# Nikola Vucevic, ORL :21.95
# Tony Bradley, UTAH :21.78
# Ivica Zubac, LAC :21.75
# Rudy Gobert, UTAH :21.72
# Chris Paul, OKC :21.72
# DeMar DeRozan, SA :21.66
# Khris Middleton, MIL :21.20
# Thomas Bryant, WSH :21.16
# Paul George, LAC :21.14
# Derrick Rose, DET :21.13
# Russell Westbrook, HOU :21.10
# Brandon Clarke, MEM :20.97
# Chris Boucher, TOR :20.76
# Domantas Sabonis, IND :20.72
# De'Aaron Fox, SAC :20.70
# Jarrett Allen, BKN :20.69
# Devin Booker, PHX :20.64
# Clint Capela, HOU :20.63
# Steven Adams, OKC :20.48
# Ben Simmons, PHI :20.47
# Nerlens Noel, OKC :20.45
# Jayson Tatum, BOS :20.45
# Bam Adebayo, MIA :20.36
# Kristaps Porzingis, DAL :20.30
# Deandre Ayton, PHX :20.08
# Kemba Walker, BOS :20.00
# DeAndre Jordan, BKN :19.95
# wait time : 5
# http://insider.espn.com/nba/hollinger/statistics/_/page/2
# Michael Porter Jr., DEN :19.84
# LaMarcus Aldridge, SA :19.78
# Richaun Holmes, SAC :19.75
# Zach LaVine, CHI :19.52
# Marquese Chriss, GS :19.50
# Danilo Gallinari, OKC :19.50
# JaVale McGee, LAL :19.39
# Jakob Poeltl, SA :19.19
# Brandon Ingram, NO :18.88
# Mason Plumlee, DEN :18.86
# Donovan Mitchell, UTAH :18.86
# Cody Zeller, CHA :18.84
# D'Angelo Russell, GS/MIN :18.77
# Dwight Howard, LAL :18.70
# Derrick Favors, NO :18.54
# T.J. Warren, IND :18.45
# Jahlil Okafor, NO :18.39
# Gordon Hayward, BOS :18.16
# Jabari Parker, ATL/SAC :18.08
# Kevin Love, CLE :17.97
# Pascal Siakam, TOR :17.96
# Spencer Dinwiddie, BKN :17.90
# Daniel Theis, BOS :17.89
# Shaquille Harrison, CHI :17.81
# Jamal Murray, DEN :17.78
# Malcolm Brogdon, IND :17.76
# Shai Gilgeous-Alexander, OKC :17.76
# Kyle Lowry, TOR :17.75
# Alex Len, ATL/SAC :17.72
# Eric Bledsoe, MIL :17.68
# Jaxson Hayes, NO :17.64
# Mo Bamba, ORL :17.57
# Julius Randle, NY :17.55
# Ja Morant, MEM :17.45
# Serge Ibaka, TOR :17.41
# Lou Williams, LAC :17.38
# Jordan Clarkson, CLE/UTAH :17.37
# Larry Nance Jr., CLE :17.37
# Jonathan Isaac, ORL :17.31
# Tobias Harris, PHI :17.25
# Gorgui Dieng, MIN/MEM :17.16
# Jrue Holiday, NO :17.09
# CJ McCollum, POR :17.08
# Willie Cauley-Stein, DAL/GS :17.06
# John Henson, CLE/DET :17.04
# Jaylen Brown, BOS :17.00
# George Hill, MIL :16.97
# Paul Millsap, DEN :16.96
# Norman Powell, TOR :16.84
# Tristan Thompson, CLE :16.82
# wait time : 4
# http://insider.espn.com/nba/hollinger/statistics/_/page/3
# Alec Burks, GS/PHI :16.78
# Dennis Schroder, OKC :16.77
# Ricky Rubio, PHX :16.53
# Cheick Diallo, PHX :16.53
# T.J. McConnell, IND :16.52
# Harry Giles III, SAC :16.51
# Derrick White, SA :16.46
# Evan Fournier, ORL :16.44
# Andrew Wiggins, GS/MIN :16.44
# Goran Dragic, MIA :16.41
# Collin Sexton, CLE :16.39
# Jordan McLaughlin, MIN :16.35
# Jaren Jackson Jr., MEM :16.33
# Fred VanVleet, TOR :16.32
# Dejounte Murray, SA :16.27
# Daniel Gafford, CHI :16.21
# Bismack Biyombo, CHA :16.18
# Taj Gibson, NY :16.14
# Caris LeVert, BKN :16.13
# Buddy Hield, SAC :16.03
# Elfrid Payton, NY :15.98
# Dwight Powell, DAL :15.96
# Devonte' Graham, CHA :15.82
# Nemanja Bjelica, SAC :15.77
# Tyus Jones, MEM :15.75
# Al Horford, PHI :15.74
# Will Barton, DEN :15.70
# Trey Burke, DAL/PHI :15.67
# Bojan Bogdanovic, UTAH :15.67
# Seth Curry, DAL :15.59
# Damian Jones, ATL :15.58
# Davis Bertans, WSH :15.53
# Wendell Carter Jr., CHI :15.51
# JJ Redick, NO :15.47
# Delon Wright, DAL :15.47
# Rudy Gay, SA :15.44
# Skal Labissiere, POR :15.38
# Michael Carter-Williams, ORL :15.37
# Naz Reid, MIN :15.35
# Aron Baynes, PHX :15.22
# Bogdan Bogdanovic, SAC :15.20
# Aaron Gordon, ORL :15.18
# Moritz Wagner, WSH :15.13
# Rondae Hollis-Jefferson, TOR :15.09
# Brook Lopez, MIL :15.02
# Kelly Oubre Jr., PHX :15.01
# Monte Morris, DEN :14.98
# Jalen Brunson, DAL :14.96
# Derrick Jones Jr., MIA :14.92
# Terry Rozier, CHA :14.90
# wait time : 6
# http://insider.espn.com/nba/hollinger/statistics/_/page/4
# Ersan Ilyasova, MIL :14.89
# Myles Turner, IND :14.87
# James Johnson, MIA/MIN :14.86
# Patty Mills, SA :14.82
# Kelly Olynyk, MIA :14.67
# Jeff Teague, ATL/MIN :14.66
# Bobby Portis, NY :14.65
# Eric Paschall, GS :14.53
# Tim Hardaway Jr., DAL :14.51
# Jerami Grant, DEN :14.46
# Omari Spellman, GS :14.45
# Shake Milton, PHI :14.44
# Doug McDermott, IND :14.43
# Luke Kennard, DET :14.40
# Marcus Morris Sr., LAC/NY :14.40
# Markelle Fultz, ORL :14.35
# Lauri Markkanen, CHI :14.32
# Frank Kaminsky, PHX :14.25
# Jordan McRae, DEN/DET/WSH :14.23
# Dario Saric, PHX :14.20
# Ian Mahinmi, WSH :14.19
# Mike Conley, UTAH :14.19
# Donte DiVincenzo, MIL :14.09
# Terrence Ross, ORL :14.06
# D.J. Augustin, ORL :14.06
# Jeremy Lamb, IND :14.05
# Ish Smith, WSH :13.96
# Terence Davis, TOR :13.88
# Shabazz Napier, MIN/WSH :13.83
# Marcus Smart, BOS :13.78
# Reggie Jackson, DET/LAC :13.76
# Thon Maker, DET :13.75
# Jeff Green, HOU/UTAH :13.72
# Troy Brown Jr., WSH :13.70
# Maxi Kleber, DAL :13.62
# Rui Hachimura, WSH :13.56
# Tomas Satoransky, CHI :13.52
# De'Anthony Melton, MEM :13.49
# Glenn Robinson III, GS/PHI :13.40
# Robert Covington, HOU/MIN :13.38
# Joe Harris, BKN :13.37
# Thaddeus Young, CHI :13.36
# Matt Thomas, TOR :13.35
# Harrison Barnes, SAC :13.30
# OG Anunoby, TOR :13.23
# Lonzo Ball, NO :13.17
# Javonte Green, BOS :13.12
# Duncan Robinson, MIA :13.12
# Denzel Valentine, CHI :13.09
# Emmanuel Mudiay, UTAH :13.07
# wait time : 6
# http://insider.espn.com/nba/hollinger/statistics/_/page/5
# Mikal Bridges, PHX :12.97
# Kendrick Nunn, MIA :12.95
# Cameron Johnson, PHX :12.94
# Gary Trent Jr., POR :12.91
# Brad Wanamaker, BOS :12.85
# Damion Lee, GS :12.75
# Raul Neto, PHI :12.72
# Malik Beasley, DEN/MIN :12.72
# Luke Kornet, CHI :12.70
# Malik Monk, CHA :12.70
# Joe Ingles, UTAH :12.64
# Trey Lyles, SA :12.63
# JaKarr Sampson, IND :12.60
# Kyle Anderson, MEM :12.57
# Draymond Green, GS :12.57
# Jae Crowder, MIA/MEM :12.57
# Markieff Morris, DET/LAL :12.57
# Patrick Beverley, LAC :12.54
# Tyler Herro, MIA :12.53
# Mike Muscala, OKC :12.51
# PJ Washington, CHA :12.48
# Rajon Rondo, LAL :12.45
# Keita Bates-Diop, DEN/MIN :12.45
# Chandler Hutchison, CHI :12.45
# Carmelo Anthony, POR :12.43
# Langston Galloway, DET :12.35
# Dorian Finney-Smith, DAL :12.35
# Kyle Kuzma, LAL :12.25
# Yogi Ferrell, SAC :12.23
# Miles Bridges, CHA :12.19
# Rodney Hood, POR :12.18
# Goga Bitadze, IND :12.17
# Kris Dunn, CHI :12.15
# Justin Holiday, IND :12.14
# Furkan Korkmaz, PHI :12.08
# Josh Richardson, PHI :12.02
# Grayson Allen, MEM :12.01
# Bruce Brown, DET :11.96
# Bruno Fernando, ATL :11.96
# Josh Hart, NO :11.95
# Blake Griffin, DET :11.94
# Coby White, CHI :11.92
# Ben McLemore, HOU :11.86
# Georges Niang, UTAH :11.79
# Marc Gasol, TOR :11.78
# Khem Birch, ORL :11.70
# Brandon Goodwin, ATL :11.70
# Isaiah Thomas, WSH :11.68
# Aaron Holiday, IND :11.64
# James Ennis III, ORL/PHI :11.57
# wait time : 5
# http://insider.espn.com/nba/hollinger/statistics/_/page/6
# Kevin Huerter, ATL :11.57
# Patrick Patterson, LAC :11.57
# Josh Okogie, MIN :11.56
# Pat Connaughton, MIL :11.56
# Nicolo Melli, NO :11.43
# Victor Oladipo, IND :11.41
# E'Twaun Moore, NO :11.38
# Abdel Nader, OKC :11.36
# Jevon Carter, PHX :11.36
# Dillon Brooks, MEM :11.35
# Kyle Korver, MIL :11.33
# Danuel House Jr., HOU :11.28
# Marvin Williams, MIL/CHA :11.27
# Mike Scott, PHI :11.24
# Sviatoslav Mykhailiuk, DET :11.21
# Bryn Forbes, SA :11.18
# JaMychal Green, LAC :11.11
# Timothe Luwawu-Cabarrot, BKN :11.04
# Kentavious Caldwell-Pope, LAL :11.01
# Trevor Ariza, POR/SAC :11.01
# Damyean Dotson, NY :10.94
# Marco Belinelli, SA :10.86
# Kevin Porter Jr., CLE :10.82
# Alex Caruso, LAL :10.79
# Torrey Craig, DEN :10.79
# Danny Green, LAL :10.79
# RJ Barrett, NY :10.76
# Gary Clark, HOU/ORL :10.74
# Cedi Osman, CLE :10.70
# Elie Okobo, PHX :10.68
# Meyers Leonard, MIA :10.67
# Garrett Temple, BKN :10.55
# Cody Martin, CHA :10.54
# Lonnie Walker IV, SA :10.52
# Austin Rivers, HOU :10.47
# Juan Hernangomez, DEN/MIN :10.45
# Dante Exum, CLE/UTAH :10.38
# Wes Iwundu, ORL :10.36
# Eric Gordon, HOU :10.31
# Jake Layman, MIN :10.30
# Isaac Bonga, WSH :10.23
# Robin Lopez, MIL :10.21
# Tyler Johnson, BKN/PHX :10.19
# Edmond Sumner, IND :10.18
# Cory Joseph, SAC :10.12
# Matisse Thybulle, PHI :10.02
# Quinn Cook, LAL :10.01
# Solomon Hill, MIA/MEM :9.86
# Frank Ntilikina, NY :9.85
# Maurice Harkless, LAC/NY :9.78
# wait time : 4
# http://insider.espn.com/nba/hollinger/statistics/_/page/7
# Gary Harris, DEN :9.78
# Tony Snell, DET :9.74
# Darius Bazley, OKC :9.64
# Nassir Little, POR :9.64
# Jarrett Culver, MIN :9.62
# DeAndre' Bembry, ATL :9.61
# Sterling Brown, MIL :9.57
# Mario Hezonja, POR :9.56
# Justin Jackson, DAL :9.50
# Royce O'Neale, UTAH :9.49
# Dzanan Musa, BKN :9.42
# Dewayne Dedmon, ATL/SAC :9.40
# Hamidou Diallo, OKC :9.36
# Kent Bazemore, POR/SAC :9.30
# Reggie Bullock, NY :9.29
# Kelan Martin, MIN :9.20
# Taurean Prince, BKN :9.19
# Ky Bowman, GS :9.18
# Nicolas Batum, CHA :9.17
# Frank Jackson, NO :9.16
# Ryan Arcidiacono, CHI :9.04
# Cam Reddish, ATL :9.03
# Anfernee Simons, POR :9.00
# Avery Bradley, LAL :8.92
# Nickeil Alexander-Walker, NO :8.92
# Rodions Kurucs, BKN :8.90
# Marko Guduric, MEM :8.82
# Alfonzo McKinnie, CLE :8.76
# De'Andre Hunter, ATL :8.66
# Darius Garland, CLE :8.54
# Brandon Knight, CLE/DET :8.54
# Landry Shamet, LAC :8.51
# Wayne Ellington, NY :8.50
# Troy Daniels, DEN/LAL :8.48
# Kevin Knox II, NY :8.38
# P.J. Tucker, HOU :8.29
# Matthew Dellavedova, CLE :8.14
# Wesley Matthews, MIL :8.10
# Grant Williams, BOS :7.91
# Semi Ojeleye, BOS :7.71
# Luguentz Dort, OKC :7.65
# Vince Carter, ATL :7.58
# Dennis Smith Jr., NY :7.48
# Kenrich Williams, NO :7.47
# Wilson Chandler, BKN :7.40
# Jerome Robinson, LAC/WSH :7.40
# Patrick McCaw, TOR :7.32
# Jordan Poole, GS :7.25
# Anthony Tolliver, POR/SAC/MEM :7.00
# Rodney McGruder, LAC :6.75
# wait time : 6
# http://insider.espn.com/nba/hollinger/statistics/_/page/8
# Treveon Graham, ATL/MIN :6.61
# Sekou Doumbouya, DET :6.26
# Dwayne Bacon, CHA :6.12
# Allen Crabbe, ATL/MIN :5.98
# Jacob Evans, GS/MIN :5.53
# Terrance Ferguson, OKC :3.71
# wait time : 5
