# %% [markdown]
# ## 台鐵時刻表
#
# [https://tip.railway.gov.tw/tra-tip-web/tip](https://tip.railway.gov.tw/tra-tip-web/tip)

# %%
import requests
from bs4 import BeautifulSoup
import time

url = 'https://tip.railway.gov.tw/tra-tip-web/tip'
staDic = {}
today = time.strftime('%Y/%m/%d')
sTime = '06:00'
eTime = '12:00'

def getTrip():
    resp = requests.get(url)
    if resp.status_code != 200:
        print('URL發生錯誤：' + url)
        return
    
    soup = BeautifulSoup(resp.text, 'html5lib')
    stations = soup.find(id = 'cityHot').ul.find_all('li')
    for station in stations:
        stationName = station.button.text
        stationId = station.button['title']
        staDic[stationName] = stationId
    
    csrf = soup.find(id = 'queryForm').find('input',{'name':'_csrf'})['value']
    formData = {
        'trainTypeList':'ALL',
        'transfer':'ONE',
        'startOrEndTime':'true',
        'startStation':staDic['臺北'],
        'endStation':staDic['新竹'],
        'rideDate':today,
        'startTime':sTime,
        'endTime':eTime, 
        '_csrf':csrf
    }
    
    queryUrl = soup.find(id='queryForm')['action']
    qResp = requests.post('https://tip.railway.gov.tw'+queryUrl, data=formData)
    qSoup = BeautifulSoup(qResp.text, 'html5lib')
    trs = qSoup.find_all('tr', 'trip-column')
    for tr in trs:
        td = tr.find_all('td')
        print('%s : %s, %s' % (td[0].ul.li.a.text, td[1].text, td[2].text)) 
        
getTrip()
# Out:
# 火車站站名與ID: 基隆, 0900-基隆
# 火車站站名與ID: 七堵, 0930-七堵
# 火車站站名與ID: 南港, 0980-南港
# 火車站站名與ID: 松山, 0990-松山
# 火車站站名與ID: 臺北, 1000-臺北
# 火車站站名與ID: 萬華, 1010-萬華
# 火車站站名與ID: 板橋, 1020-板橋
# 火車站站名與ID: 樹林, 1040-樹林
# 火車站站名與ID: 桃園, 1080-桃園
# 火車站站名與ID: 中壢, 1100-中壢
# 火車站站名與ID: 新竹, 1210-新竹
# 火車站站名與ID: 竹南, 1250-竹南
# 火車站站名與ID: 苗栗, 3160-苗栗
# 火車站站名與ID: 豐原, 3230-豐原
# 火車站站名與ID: 臺中, 3300-臺中
# 火車站站名與ID: 彰化, 3360-彰化
# 火車站站名與ID: 員林, 3390-員林
# 火車站站名與ID: 斗六, 3470-斗六
# 火車站站名與ID: 嘉義, 4080-嘉義
# 火車站站名與ID: 新營, 4120-新營
# 火車站站名與ID: 臺南, 4220-臺南
# 火車站站名與ID: 岡山, 4310-岡山
# 火車站站名與ID: 新左營, 4340-新左營
# 火車站站名與ID: 高雄, 4400-高雄
# 火車站站名與ID: 屏東, 5000-屏東
# 火車站站名與ID: 潮州, 5050-潮州
# 火車站站名與ID: 臺東, 6000-臺東
# 火車站站名與ID: 玉里, 6110-玉里
# 火車站站名與ID: 花蓮, 7000-花蓮
# 火車站站名與ID: 蘇澳新, 7130-蘇澳新
# 火車站站名與ID: 宜蘭, 7190-宜蘭
# 火車站站名與ID: 瑞芳, 7360-瑞芳
# 傳送資料：1000-臺北, 1210-新竹, 2020/01/06, 06:00, 12:00
# 莒光1 : 06:10, 07:18
# 區間1117 : 06:18, 07:56
# 自強103 : 06:27, 07:35
# 區間1121 : 06:40, 08:19
# 自強105 : 07:00, 08:11
# 區間2143 : 07:04, 08:35
# 莒光507 : 07:13, 08:47
# 區間1127 : 07:24, 09:02
# 區間1131 : 07:35, 09:15
# 區間2153 : 08:03, 09:47
# 莒光2 : 08:10, 20:29
# 自強109 : 08:13, 09:21
# 自強113 : 08:28, 09:36
# 區間1137 : 08:32, 10:02
# 區間1141 : 08:48, 10:25
# 自強115 : 08:59, 10:11
# 區間2163 : 09:06, 10:36
# 莒光511 : 09:17, 10:43
# 區間1147 : 09:26, 10:57
# 區間1151 : 09:44, 11:25
# 自強117 : 10:00, 11:08
# 區間2173 : 10:05, 11:35
# 區間1157 : 10:25, 12:01
# 自強119 : 10:40, 11:48
# 區間1161 : 10:45, 12:22
# 自強121 : 11:00, 12:08
# 區間2183 : 11:06, 12:36
# 莒光513 : 11:18, 12:47
# 自強123 : 11:58, 13:06
