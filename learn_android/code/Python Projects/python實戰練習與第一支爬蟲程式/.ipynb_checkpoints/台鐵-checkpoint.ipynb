# %%
import requests
from bs4 import BeautifulSoup
import time


url = 'https://tip.railway.gov.tw/tra-tip-web/tip'
staDic = {}
today = time.strftime('@Y/@m/@d')
sTime = '06:00'
eTime = '12:00'


def getTrip():
    resp = requests.get(url)
    if resp.status_code != 200:
        print('網頁發生錯誤' + url)
        return
    
    soup = BeautifulSoup(resp.text,'html5lib')
    
    stations = soup.find(id = 'cityHot').ul.find_all('li')
    
    for station in stations:
        stationName = station.button.text
        stationId = station.button['title']
        staDic[stationName] = stationId
        print(staDic)
        
    csrf = soup.find(id = 'queryForm').find('input',{'name':'_csrf'})['value']
    formData = {
        'trainTypeList':'ALL',
        'transfer':'ONE',
        'startOrEndTime':'true',
        'startStation':staDic['臺北'],
        'endStation':staDic['新竹'],
        'rideDate':'2021/01/05',
        'startTime':sTime,
        'endTime':eTime, 
        '_csrf':csrf
    }
    
    
    queryUrl = soup.find(id='queryForm')['action']
    qResp = requests.post('https://tip.railway.gov.tw/tra-tip-web/tip/tip001/tip112/querybytime', data=formData)
    qSoup = BeautifulSoup(qResp.text, 'html5lib')
    trs = qSoup.find_all('tr', 'trip-column')
    for tr in trs:
        td = tr.find_all('td')
        print('%s : %s, %s' % (td[0].ul.li.a.text, td[1].text, td[2].text)) 
        
getTrip()
# Out:
# {'基隆': '0900-基隆'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南', '岡山': '4310-岡山'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南', '岡山': '4310-岡山', '新左營': '4340-新左營'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南', '岡山': '4310-岡山', '新左營': '4340-新左營', '高雄': '4400-高雄'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南', '岡山': '4310-岡山', '新左營': '4340-新左營', '高雄': '4400-高雄', '屏東': '5000-屏東'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南', '岡山': '4310-岡山', '新左營': '4340-新左營', '高雄': '4400-高雄', '屏東': '5000-屏東', '潮州': '5050-潮州'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南', '岡山': '4310-岡山', '新左營': '4340-新左營', '高雄': '4400-高雄', '屏東': '5000-屏東', '潮州': '5050-潮州', '臺東': '6000-臺東'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南', '岡山': '4310-岡山', '新左營': '4340-新左營', '高雄': '4400-高雄', '屏東': '5000-屏東', '潮州': '5050-潮州', '臺東': '6000-臺東', '玉里': '6110-玉里'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南', '岡山': '4310-岡山', '新左營': '4340-新左營', '高雄': '4400-高雄', '屏東': '5000-屏東', '潮州': '5050-潮州', '臺東': '6000-臺東', '玉里': '6110-玉里', '花蓮': '7000-花蓮'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南', '岡山': '4310-岡山', '新左營': '4340-新左營', '高雄': '4400-高雄', '屏東': '5000-屏東', '潮州': '5050-潮州', '臺東': '6000-臺東', '玉里': '6110-玉里', '花蓮': '7000-花蓮', '蘇澳新': '7130-蘇澳新'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南', '岡山': '4310-岡山', '新左營': '4340-新左營', '高雄': '4400-高雄', '屏東': '5000-屏東', '潮州': '5050-潮州', '臺東': '6000-臺東', '玉里': '6110-玉里', '花蓮': '7000-花蓮', '蘇澳新': '7130-蘇澳新', '宜蘭': '7190-宜蘭'}
# {'基隆': '0900-基隆', '七堵': '0930-七堵', '南港': '0980-南港', '松山': '0990-松山', '臺北': '1000-臺北', '萬華': '1010-萬華', '板橋': '1020-板橋', '樹林': '1040-樹林', '桃園': '1080-桃園', '中壢': '1100-中壢', '新竹': '1210-新竹', '竹南': '1250-竹南', '苗栗': '3160-苗栗', '豐原': '3230-豐原', '臺中': '3300-臺中', '彰化': '3360-彰化', '員林': '3390-員林', '斗六': '3470-斗六', '嘉義': '4080-嘉義', '新營': '4120-新營', '臺南': '4220-臺南', '岡山': '4310-岡山', '新左營': '4340-新左營', '高雄': '4400-高雄', '屏東': '5000-屏東', '潮州': '5050-潮州', '臺東': '6000-臺東', '玉里': '6110-玉里', '花蓮': '7000-花蓮', '蘇澳新': '7130-蘇澳新', '宜蘭': '7190-宜蘭', '瑞芳': '7360-瑞芳'}
