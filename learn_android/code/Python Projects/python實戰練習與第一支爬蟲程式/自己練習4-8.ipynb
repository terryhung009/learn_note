# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import random

url = 'http://insider.espn.com/nba/hollinger/statistics/_/page/'

try:
    options = webdriver.ChromeOptions()
    
    chrome = webdriver.Chrome(options=options,
                             executable_path='./chromedriver')
    chrome.set_page_load_timeout(10)
    for i in range(1, 9):
        _url = url + str(i)
        print(_url)
        chrome.get(_url)
        soup = BeautifulSoup(chrome.page_source, 'html5lib')
        trs = soup.find('tbody').find_all('tr')
        for tr in trs:
            tds = [td for td in tr.children]
            rk = tds[0].text.strip()
            if rk =='RK' or len(tds)<2:
                continue
            name = tds[1].text
            per = tds[11].text
            print('%s :%s' % (name, per))
        wait = random.randint(2,6)
        print('wait time : %d' % wait)
        time.sleep(wait)
    
    
finally:
    chrome.quit()
# Out:
# http://insider.espn.com/nba/hollinger/statistics/_/page/1
# Ja Morant, MEM :32.06
# James Harden, HOU :31.66
# Nikola Jokic, DEN :29.72
# Stephen Curry, GS :28.39
# Giannis Antetokounmpo, MIL :28.16
# Nikola Vucevic, ORL :27.94
# Joel Embiid, PHI :27.71
# Trae Young, ATL :27.38
# Jarred Vanderbilt, MIN :27.25
# Kevin Durant, BKN :26.80
# Enes Kanter, POR :26.69
# Michael Porter Jr., DEN :26.68
# CJ McCollum, POR :26.57
# Alec Burks, NY :26.55
# Robert Williams III, BOS :26.40
# Kyrie Irving, BKN :26.30
# Karl-Anthony Towns, MIN :25.93
# Jaylen Brown, BOS :25.84
# Paul George, LAC :24.74
# LeBron James, LAL :24.53
# Christian Wood, HOU :24.48
# Ivica Zubac, LAC :24.40
# DeMar DeRozan, SA :24.33
# Chris Boucher, TOR :24.31
# Luka Doncic, DAL :24.23
# Derrick Favors, UTAH :24.13
# Jayson Tatum, BOS :24.09
# Khris Middleton, MIL :23.67
# Brandon Ingram, NO :23.53
# Bam Adebayo, MIA :23.50
# Rudy Gobert, UTAH :23.35
# Bradley Beal, WSH :23.28
# Immanuel Quickley, NY :23.20
# Kawhi Leonard, LAC :23.09
# Malcolm Brogdon, IND :23.06
# Anthony Davis, LAL :23.02
# Denzel Valentine, CHI :22.93
# Jarrett Allen, BKN :22.87
# Tobias Harris, PHI :22.67
# Jordan Clarkson, UTAH :22.41
# John Collins, ATL :22.05
# Jrue Holiday, MIL :21.86
# Gorgui Dieng, MEM :21.71
# Montrezl Harrell, LAL :21.52
# Domantas Sabonis, IND :21.37
# Thomas Bryant, WSH :21.32
# Fred VanVleet, TOR :21.27
# Terrence Ross, ORL :21.12
# Daniel Gafford, CHI :21.12
# Victor Oladipo, IND :21.06
# wait time : 4
# http://insider.espn.com/nba/hollinger/statistics/_/page/2
# Damian Lillard, POR :21.02
# Eric Gordon, HOU :20.98
# Mike Conley, UTAH :20.85
# George Hill, OKC :20.71
# Clint Capela, ATL :20.61
# Zion Williamson, NO :20.60
# Andre Drummond, CLE :20.56
# Jahlil Okafor, DET :20.44
# Jamal Murray, DEN :20.35
# Deandre Ayton, PHX :20.28
# Serge Ibaka, LAC :20.20
# Collin Sexton, CLE :20.16
# Jalen Brunson, DAL :20.15
# Cameron Johnson, PHX :20.15
# Lauri Markkanen, CHI :19.92
# Otto Porter Jr., CHI :19.68
# Seth Curry, PHI :19.51
# Donte DiVincenzo, MIL :19.48
# Richaun Holmes, SAC :19.43
# Raul Neto, WSH :19.38
# Julius Randle, NY :19.35
# Bobby Portis, MIL :19.17
# John Wall, HOU :19.04
# Terry Rozier, CHA :18.91
# JaVale McGee, CLE :18.69
# Chris Paul, PHX :18.68
# Aaron Gordon, ORL :18.67
# Myles Turner, IND :18.66
# Jonas Valanciunas, MEM :18.59
# Tyrese Haliburton, SAC :18.59
# Mason Plumlee, DET :18.56
# Patty Mills, SA :18.47
# JaMychal Green, DEN :18.41
# John Konchar, MEM :18.39
# Steven Adams, NO :18.32
# Malik Beasley, MIN :18.28
# Evan Fournier, ORL :18.27
# Zach LaVine, CHI :18.26
# Eric Paschall, GS :18.26
# Josh Jackson, DET :18.16
# Jerami Grant, DET :18.08
# Naz Reid, MIN :18.07
# Avery Bradley, MIA :18.06
# De'Aaron Fox, SAC :18.01
# Caleb Martin, CHA :18.00
# Keldon Johnson, SA :17.94
# Goran Dragic, MIA :17.92
# Mitchell Robinson, NY :17.79
# Willie Cauley-Stein, DAL :17.71
# Isaiah Hartenstein, DEN :17.68
# wait time : 2
# http://insider.espn.com/nba/hollinger/statistics/_/page/3
# Mikal Bridges, PHX :17.43
# Wayne Ellington, DET :17.32
# Khem Birch, ORL :17.26
# Ben Simmons, PHI :17.24
# Cameron Payne, PHX :17.04
# Rui Hachimura, WSH :16.97
# Harrison Barnes, SAC :16.96
# Derrick Rose, DET :16.83
# Langston Galloway, PHX :16.70
# De'Andre Hunter, ATL :16.62
# Tim Hardaway Jr., DAL :16.54
# LaMelo Ball, CHA :16.51
# Mike Muscala, OKC :16.48
# Monte Morris, DEN :16.36
# Gordon Hayward, CHA :16.32
# Sterling Brown, HOU :16.22
# Talen Horton-Tucker, LAL :16.18
# Hassan Whiteside, SAC :16.03
# Kyle Lowry, TOR :15.88
# Marcus Smart, BOS :15.87
# Jimmy Butler, MIA :15.79
# Pat Connaughton, MIL :15.78
# Dario Saric, PHX :15.77
# Gary Trent Jr., POR :15.65
# Luguentz Dort, OKC :15.58
# Shai Gilgeous-Alexander, OKC :15.55
# Kentavious Caldwell-Pope, LAL :15.46
# Joe Harris, BKN :15.40
# Reggie Jackson, LAC :15.39
# Russell Westbrook, WSH :15.39
# Terence Davis, TOR :15.18
# Facundo Campazzo, DEN :15.09
# Blake Griffin, DET :15.07
# Dejounte Murray, SA :14.96
# Svi Mykhailiuk, DET :14.88
# Kevin Huerter, ATL :14.83
# Kelly Olynyk, MIA :14.82
# Paul Millsap, DEN :14.80
# Matt Thomas, TOR :14.80
# Maxi Kleber, DAL :14.79
# Nicolas Batum, LAC :14.70
# Tristan Thompson, BOS :14.69
# Hamidou Diallo, OKC :14.65
# Dwight Howard, PHI :14.65
# Lou Williams, LAC :14.65
# T.J. McConnell, IND :14.63
# Jakob Poeltl, SA :14.62
# Larry Nance Jr., CLE :14.60
# Dennis Schroder, LAL :14.52
# Delon Wright, DET :14.51
# wait time : 3
# http://insider.espn.com/nba/hollinger/statistics/_/page/4
# Darius Garland, CLE :14.48
# Marc Gasol, LAL :14.32
# Damion Lee, GS :14.30
# Kyle Anderson, MEM :14.27
# Bismack Biyombo, CHA :14.26
# Carmelo Anthony, POR :14.19
# Caris LeVert, BKN :14.14
# Nickeil Alexander-Walker, NO :13.90
# Isaiah Roby, OKC :13.87
# Nemanja Bjelica, SAC :13.83
# Precious Achiuwa, MIA :13.68
# Jaxson Hayes, NO :13.67
# Jeff Teague, BOS :13.59
# Joe Ingles, UTAH :13.59
# Austin Rivers, NY :13.57
# Jordan Nwora, MIL :13.56
# Tomas Satoransky, CHI :13.55
# Payton Pritchard, BOS :13.55
# Wendell Carter Jr., CHI :13.50
# Eric Bledsoe, NO :13.42
# Al Horford, OKC :13.40
# Devin Booker, PHX :13.30
# Shake Milton, PHI :13.29
# Jusuf Nurkic, POR :13.26
# Donovan Mitchell, UTAH :13.22
# Cedi Osman, CLE :13.22
# Darius Bazley, OKC :13.20
# Kevon Looney, GS :13.16
# James Wiseman, GS :13.09
# Mychal Mulder, GS :13.03
# Anthony Edwards, MIN :12.99
# Isaiah Stewart, DET :12.98
# Rudy Gay, SA :12.98
# Brook Lopez, MIL :12.96
# Elfrid Payton, NY :12.86
# Cole Anthony, ORL :12.85
# RJ Barrett, NY :12.81
# T.J. Warren, IND :12.77
# Davis Bertans, WSH :12.75
# Ricky Rubio, MIN :12.59
# Bogdan Bogdanovic, ATL :12.57
# Tyler Herro, MIA :12.55
# PJ Dozier, DEN :12.55
# Isaac Bonga, WSH :12.55
# D'Angelo Russell, MIN :12.54
# Sekou Doumbouya, DET :12.51
# Markelle Fultz, ORL :12.33
# Deni Avdija, WSH :12.32
# P.J. Washington, CHA :12.22
# Wesley Matthews, LAL :12.20
# wait time : 5
# http://insider.espn.com/nba/hollinger/statistics/_/page/5
# D.J. Augustin, MIL :12.06
# Jordan McLaughlin, MIN :12.06
# Jordan Poole, GS :12.00
# Nerlens Noel, NY :11.99
# Jae Crowder, PHX :11.99
# Lonzo Ball, NO :11.96
# Ed Davis, MIN :11.92
# Andrew Wiggins, GS :11.88
# Dillon Brooks, MEM :11.86
# DeAndre Jordan, BKN :11.85
# Josh Richardson, DAL :11.68
# Juan Toscano-Anderson, GS :11.60
# Kyle Kuzma, LAL :11.53
# Dwight Powell, DAL :11.52
# Robin Lopez, WSH :11.52
# Kevin Love, CLE :11.49
# Tyus Jones, MEM :11.48
# Daniel Theis, BOS :11.48
# Jake Layman, MIN :11.35
# Timothe Luwawu-Cabarrot, BKN :11.28
# OG Anunoby, TOR :11.21
# Doug McDermott, IND :11.20
# Cody Martin, CHA :11.20
# Pascal Siakam, TOR :11.19
# Jarrett Culver, MIN :11.17
# Justin Holiday, IND :11.11
# Miles Bridges, CHA :11.09
# Desmond Bane, MEM :11.05
# Jeff Green, BKN :11.03
# Josh Hart, NO :11.03
# Danny Green, PHI :11.01
# Thaddeus Young, CHI :10.93
# Patrick Beverley, LAC :10.70
# James Johnson, DAL :10.69
# Lonnie Walker IV, SA :10.62
# Brandon Clarke, MEM :10.58
# Dorian Finney-Smith, DAL :10.53
# Kent Bazemore, GS :10.50
# Will Barton, DEN :10.50
# Spencer Dinwiddie, BKN :10.50
# Cory Joseph, SAC :10.42
# Kendrick Nunn, MIA :10.34
# Bryn Forbes, MIL :10.21
# Coby White, CHI :10.13
# Markieff Morris, LAL :10.07
# Bojan Bogdanovic, UTAH :9.99
# Luke Kennard, LAC :9.96
# Semi Ojeleye, BOS :9.71
# Jalen McDaniels, CHA :9.70
# Grant Williams, BOS :9.61
# wait time : 3
# http://insider.espn.com/nba/hollinger/statistics/_/page/6
# LaMarcus Aldridge, SA :9.50
# Duncan Robinson, MIA :9.49
# Anfernee Simons, POR :9.47
# Josh Okogie, MIN :9.44
# Saddiq Bey, DET :9.28
# David Nwaba, HOU :9.26
# Royce O'Neale, UTAH :9.21
# Jae'Sean Tate, HOU :9.17
# Patrick Williams, CHI :9.15
# Devonte' Graham, CHA :9.07
# Buddy Hield, SAC :9.05
# Ish Smith, WSH :9.05
# Taurean Prince, BKN :9.03
# Cam Reddish, ATL :8.94
# Matisse Thybulle, PHI :8.91
# Tyrese Maxey, PHI :8.89
# Bruno Fernando, ATL :8.87
# Glenn Robinson III, SAC :8.79
# Trey Burke, DAL :8.60
# Brandon Goodwin, ATL :8.43
# Stanley Johnson, TOR :8.38
# Alex Len, TOR :8.37
# Damyean Dotson, CLE :8.34
# Chuma Okeke, ORL :8.34
# Dwayne Bacon, ORL :8.22
# Brad Wanamaker, GS :8.02
# Draymond Green, GS :7.97
# Kelly Oubre Jr., GS :7.74
# Kevin Knox II, NY :7.55
# Devin Vassell, SA :7.25
# Robert Covington, POR :7.20
# Marvin Bagley III, SAC :7.16
# D.J. Wilson, MIL :7.14
# Danuel House Jr., HOU :7.09
# Michael Carter-Williams, ORL :6.99
# Aaron Holiday, IND :6.65
# Theo Maledon, OKC :6.65
# Aron Baynes, TOR :6.51
# Thanasis Antetokounmpo, MIL :6.27
# Dante Exum, CLE :6.26
# Gary Clark, ORL :6.16
# Norman Powell, TOR :5.91
# Derrick Jones Jr., POR :5.90
# Grayson Allen, MEM :5.78
# Kenrich Williams, OKC :5.58
# Garrett Temple, CHI :5.45
# Reggie Bullock, NY :5.36
# Mike Scott, PHI :5.21
# P.J. Tucker, HOU :5.08
# Solomon Hill, ATL :4.98
# wait time : 3
# http://insider.espn.com/nba/hollinger/statistics/_/page/7
# Drew Eubanks, SA :4.76
# Troy Brown Jr., WSH :4.71
# Justin Jackson, OKC :4.62
# Gary Harris, DEN :4.61
# Nicolo Melli, NO :4.26
# Andre Iguodala, MIA :4.22
# Jerome Robinson, WSH :4.14
# Chandler Hutchison, CHI :4.10
# Rodney Hood, POR :4.06
# Patrick Patterson, LAC :3.93
# Landry Shamet, BKN :3.90
# JJ Redick, NO :3.37
# Isaac Okoro, CLE :3.30
# Juancho Hernangomez, MIN :2.77
# Sean McDermott, MEM :2.59
# Terance Mann, LAC :2.56
# Jevon Carter, PHX :2.11
# Dean Wade, CLE :1.89
# Furkan Korkmaz, PHI :0.56
# Killian Hayes, DET :-0.82
# Aleksej Pokusevski, OKC :-3.03
# Georges Niang, UTAH :-3.69
# Maurice Harkless, MIA :-4.86
# wait time : 2
# http://insider.espn.com/nba/hollinger/statistics/_/page/8
# wait time : 4
